# %% [markdown]
# # Mod18 DataFrame Plots

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
# %matplotlib inline
#%matplotlib notebook

# %% [markdown]
# ### Histograms

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

# %%
df.head()
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0
# 3   jeff   19      M          dc             3         5
# 4   bill   45      M  california             2         2

# %%
# df[['age']].plot(kind='hist',bins=[0,20,40,60,80,100],rwidth=0.8,legend=False)
df[['age']].plot(kind='hist',bins=15,rwidth=0.8,legend=False)
# 切資料群組
plt.show()

# %%
np.random.seed(123456)
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df4.head()
# Out:
#           a         b         c
# 0  1.469112 -0.218470  0.994515
# 1  0.717137 -0.061645 -0.653177
# 2 -0.509059 -0.723780 -0.645266
# 3 -0.135632  0.551225  0.185464
# 4  2.212112 -0.497767 -1.799739

# %%
# Create a new figure
fig=plt.figure();

# %%
df4.plot.hist(alpha=0.8,bins=50 );

# %%
df4.plot.hist(stacked=True, bins=20);

# %% [markdown]
# ### Scatter plot

# %%
# a scatter plot comparing num_children and num_pets
df.plot(kind='scatter',x='num_children',y='num_pets',color='red');

# %%
np.random.seed(123456)
df5 = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df5.head(5)
# Out:
#           a         b         c         d
# 0  0.126970  0.966718  0.260476  0.897237
# 1  0.376750  0.336222  0.451376  0.840255
# 2  0.123102  0.543026  0.373012  0.447997
# 3  0.129441  0.859879  0.820388  0.352054
# 4  0.228887  0.776784  0.594784  0.137554

# %%
df5.plot.scatter(x='a', y='b', marker='o');

# %%
plt.plot(df5['c'], df5['d'], 'p', color='black',
         markersize=7,
         markerfacecolor='g',
         markeredgecolor='r',
         markeredgewidth=2)
plt.xlim(0, 1);

# %% [markdown]
# ### Area plot

# %%
np.random.seed(123456)
df6 = pd.DataFrame(np.random.randint(0,30, (5,4)), columns=['a', 'b', 'c', 'd'])

# %%
df6.head()
# Out:
#     a   b   c   d
# 0   1  10  18  17
# 1  24  11  15  11
# 2  27   0  23   4
# 3   8  10  10  12
# 4  11  20  11  15

# %%
df6.plot.area(alpha=0.5);

# %%
ax = df6.plot.area()
ax.legend(loc='upper center', ncol=4)
plt.ylim(0,70)
plt.plot();

# %%
ax = df6.plot.area(stacked=False)
ax.legend(frameon=True, shadow=True)
plt.plot();

# %%
x=np.arange(df6.shape[0])
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax1.stackplot(x,df6['a'],df6['b'])
ax2.stackplot(x,df6['c'],df6['d'],colors=['red','green']);
